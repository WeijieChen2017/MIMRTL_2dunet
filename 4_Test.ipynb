# %%
import os
os.chdir('pytorch-CycleGAN-and-pix2pix/')

# %%
# !python test.py --dataroot ./datasets/subj01_t1b_inv --direction BtoA --model test --name 2d_enhanced_v4 --netG unet_256 --dataset_mode single --norm batch --num_test 300
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/subj01_t1b_inv     	[default: None]
#              dataset_mode: single
#                 direction: BtoA                          	[default: AtoB]
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: 2d_enhanced_v4                	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256                      	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                   no_flip: False
#                      norm: batch                         	[default: instance]
#                     ntest: inf
#                  num_test: 300                           	[default: 50]
#               num_threads: 4
#                 output_nc: 3
#                     phase: test
#                preprocess: resize_and_crop
#               results_dir: ./results/
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# dataset [SingleDataset] was created
# initialize network with normal
# model [TestModel] was created
# loading the model from ./checkpoints/2d_enhanced_v4/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.414 M
# -----------------------------------------------
# creating web directory ./results/2d_enhanced_v4/test_latest
# processing (0000)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_0.npy']
# processing (0005)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_102.npy']
# processing (0010)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_107.npy']
# processing (0015)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_111.npy']
# processing (0020)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_116.npy']
# processing (0025)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_120.npy']
# processing (0030)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_125.npy']
# processing (0035)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_13.npy']
# processing (0040)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_134.npy']
# processing (0045)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_139.npy']
# processing (0050)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_143.npy']
# processing (0055)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_148.npy']
# processing (0060)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_152.npy']
# processing (0065)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_157.npy']
# processing (0070)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_161.npy']
# processing (0075)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_166.npy']
# processing (0080)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_170.npy']
# processing (0085)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_175.npy']
# processing (0090)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_18.npy']
# processing (0095)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_184.npy']
# processing (0100)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_189.npy']
# processing (0105)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_193.npy']
# processing (0110)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_198.npy']
# processing (0115)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_201.npy']
# processing (0120)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_206.npy']
# processing (0125)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_210.npy']
# processing (0130)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_215.npy']
# processing (0135)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_22.npy']
# processing (0140)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_224.npy']
# processing (0145)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_229.npy']
# processing (0150)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_233.npy']
# processing (0155)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_238.npy']
# processing (0160)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_242.npy']
# processing (0165)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_247.npy']
# processing (0170)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_251.npy']
# processing (0175)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_256.npy']
# processing (0180)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_260.npy']
# processing (0185)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_265.npy']
# processing (0190)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_27.npy']
# processing (0195)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_274.npy']
# processing (0200)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_279.npy']
# processing (0205)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_283.npy']
# processing (0210)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_32.npy']
# processing (0215)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_37.npy']
# processing (0220)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_41.npy']
# processing (0225)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_46.npy']
# processing (0230)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_50.npy']
# processing (0235)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_55.npy']
# processing (0240)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_6.npy']
# processing (0245)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_64.npy']
# processing (0250)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_69.npy']
# processing (0255)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_73.npy']
# processing (0260)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_78.npy']
# processing (0265)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_82.npy']
# processing (0270)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_87.npy']
# processing (0275)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_91.npy']
# processing (0280)-th image... ['./datasets/subj01_t1b_inv/test/subj01_pet_96.npy']
# processing (0285)-th image... ['./datasets/subj01_t1b_inv/train/fwhm_9_subj01_t1bravo_brain_inv_mask_p1radon_NO_1.npy']
# processing (0290)-th image... ['./datasets/subj01_t1b_inv/train/fwhm_9_subj01_t1bravo_brain_inv_mask_p1radon_NO_103.npy']
# processing (0295)-th image... ['./datasets/subj01_t1b_inv/train/fwhm_9_subj01_t1bravo_brain_inv_mask_p1radon_NO_108.npy']

# %%
para = ['6','8','8R']
basic_command_1 = "python test.py --dataroot ./datasets/subj01_t1b_inv --direction BtoA --model test"
basic_command_2 = " --name 2d_enhanced_sk"
basic_command_3 = " --netG unet_256 --dataset_mode single --norm batch --num_test 300"

# %%
for sk in para:
    command = basic_command_1 + basic_command_2 + sk + basic_command_3
    print(command)
    os.system(command)
# Out:
# python test.py --dataroot ./datasets/subj01_t1b_inv --direction BtoA --model test --name 2d_enhanced_sk6 --netG unet_256 --dataset_mode single --norm batch --num_test 300
# python test.py --dataroot ./datasets/subj01_t1b_inv --direction BtoA --model test --name 2d_enhanced_sk8 --netG unet_256 --dataset_mode single --norm batch --num_test 300
# python test.py --dataroot ./datasets/subj01_t1b_inv --direction BtoA --model test --name 2d_enhanced_sk8R --netG unet_256 --dataset_mode single --norm batch --num_test 300

# %%
# !python test.py --dataroot ./datasets/pet_test --direction BtoA --model test --name 2d_enhanced_sk8R_2x_512 --netG unet_512 --dataset_mode single --norm batch --num_test 300
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/pet_test           	[default: None]
#              dataset_mode: single
#                 direction: BtoA                          	[default: AtoB]
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: 2d_enhanced_sk8R_2x_512       	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_512                      	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                   no_flip: False
#                      norm: batch                         	[default: instance]
#                     ntest: inf
#                  num_test: 300                           	[default: 50]
#               num_threads: 4
#                 output_nc: 3
#                     phase: test
#                preprocess: resize_and_crop
#               results_dir: ./results/
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# dataset [SingleDataset] was created
# initialize network with normal
# model [TestModel] was created
# loading the model from ./checkpoints/2d_enhanced_sk8R_2x_512/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 79.584 M
# -----------------------------------------------
# creating web directory ./results/2d_enhanced_sk8R_2x_512/test_latest
# processing (0000)-th image... ['./datasets/pet_test/test/subj01_pet_0.npy']
# processing (0005)-th image... ['./datasets/pet_test/test/subj01_pet_102.npy']
# processing (0010)-th image... ['./datasets/pet_test/test/subj01_pet_107.npy']
# processing (0015)-th image... ['./datasets/pet_test/test/subj01_pet_111.npy']
# processing (0020)-th image... ['./datasets/pet_test/test/subj01_pet_116.npy']
# processing (0025)-th image... ['./datasets/pet_test/test/subj01_pet_120.npy']
# processing (0030)-th image... ['./datasets/pet_test/test/subj01_pet_125.npy']
# processing (0035)-th image... ['./datasets/pet_test/test/subj01_pet_13.npy']
# processing (0040)-th image... ['./datasets/pet_test/test/subj01_pet_134.npy']
# processing (0045)-th image... ['./datasets/pet_test/test/subj01_pet_139.npy']
# processing (0050)-th image... ['./datasets/pet_test/test/subj01_pet_143.npy']
# processing (0055)-th image... ['./datasets/pet_test/test/subj01_pet_148.npy']
# processing (0060)-th image... ['./datasets/pet_test/test/subj01_pet_152.npy']
# processing (0065)-th image... ['./datasets/pet_test/test/subj01_pet_157.npy']
# processing (0070)-th image... ['./datasets/pet_test/test/subj01_pet_161.npy']
# processing (0075)-th image... ['./datasets/pet_test/test/subj01_pet_166.npy']
# processing (0080)-th image... ['./datasets/pet_test/test/subj01_pet_170.npy']
# processing (0085)-th image... ['./datasets/pet_test/test/subj01_pet_175.npy']
# processing (0090)-th image... ['./datasets/pet_test/test/subj01_pet_18.npy']
# processing (0095)-th image... ['./datasets/pet_test/test/subj01_pet_184.npy']
# processing (0100)-th image... ['./datasets/pet_test/test/subj01_pet_189.npy']
# processing (0105)-th image... ['./datasets/pet_test/test/subj01_pet_193.npy']
# processing (0110)-th image... ['./datasets/pet_test/test/subj01_pet_198.npy']
# processing (0115)-th image... ['./datasets/pet_test/test/subj01_pet_201.npy']
# processing (0120)-th image... ['./datasets/pet_test/test/subj01_pet_206.npy']
# processing (0125)-th image... ['./datasets/pet_test/test/subj01_pet_210.npy']
# processing (0130)-th image... ['./datasets/pet_test/test/subj01_pet_215.npy']
# processing (0135)-th image... ['./datasets/pet_test/test/subj01_pet_22.npy']
# processing (0140)-th image... ['./datasets/pet_test/test/subj01_pet_224.npy']
# processing (0145)-th image... ['./datasets/pet_test/test/subj01_pet_229.npy']
# processing (0150)-th image... ['./datasets/pet_test/test/subj01_pet_233.npy']
# processing (0155)-th image... ['./datasets/pet_test/test/subj01_pet_238.npy']
# processing (0160)-th image... ['./datasets/pet_test/test/subj01_pet_242.npy']
# processing (0165)-th image... ['./datasets/pet_test/test/subj01_pet_247.npy']
# processing (0170)-th image... ['./datasets/pet_test/test/subj01_pet_251.npy']
# processing (0175)-th image... ['./datasets/pet_test/test/subj01_pet_256.npy']
# processing (0180)-th image... ['./datasets/pet_test/test/subj01_pet_260.npy']
# processing (0185)-th image... ['./datasets/pet_test/test/subj01_pet_265.npy']
# processing (0190)-th image... ['./datasets/pet_test/test/subj01_pet_27.npy']
# processing (0195)-th image... ['./datasets/pet_test/test/subj01_pet_274.npy']
# processing (0200)-th image... ['./datasets/pet_test/test/subj01_pet_279.npy']
# processing (0205)-th image... ['./datasets/pet_test/test/subj01_pet_283.npy']
# processing (0210)-th image... ['./datasets/pet_test/test/subj01_pet_32.npy']
# processing (0215)-th image... ['./datasets/pet_test/test/subj01_pet_37.npy']
# processing (0220)-th image... ['./datasets/pet_test/test/subj01_pet_41.npy']
# processing (0225)-th image... ['./datasets/pet_test/test/subj01_pet_46.npy']
# processing (0230)-th image... ['./datasets/pet_test/test/subj01_pet_50.npy']
# processing (0235)-th image... ['./datasets/pet_test/test/subj01_pet_55.npy']
# processing (0240)-th image... ['./datasets/pet_test/test/subj01_pet_6.npy']
# processing (0245)-th image... ['./datasets/pet_test/test/subj01_pet_64.npy']
# processing (0250)-th image... ['./datasets/pet_test/test/subj01_pet_69.npy']
# processing (0255)-th image... ['./datasets/pet_test/test/subj01_pet_73.npy']
# processing (0260)-th image... ['./datasets/pet_test/test/subj01_pet_78.npy']
# processing (0265)-th image... ['./datasets/pet_test/test/subj01_pet_82.npy']
# processing (0270)-th image... ['./datasets/pet_test/test/subj01_pet_87.npy']
# processing (0275)-th image... ['./datasets/pet_test/test/subj01_pet_91.npy']
# processing (0280)-th image... ['./datasets/pet_test/test/subj01_pet_96.npy']

# %%
# !python test.py --dataroot datasets/subj01_t1b_inv/test --name sk8R --model test --no_dropout --netG unet_256 --num_test 300
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: datasets/subj01_t1b_inv/test  	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: sk8R                          	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256                      	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: True                          	[default: False]
#                   no_flip: False
#                      norm: instance
#                     ntest: inf
#                  num_test: 300                           	[default: 50]
#               num_threads: 4
#                 output_nc: 3
#                     phase: test
#                preprocess: resize_and_crop
#               results_dir: ./results/
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# dataset [SingleDataset] was created
# initialize network with normal
# model [TestModel] was created
# loading the model from ./checkpoints/sk8R/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.410 M
# -----------------------------------------------
# creating web directory ./results/sk8R/test_latest
# processing (0000)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_0.npy']
# processing (0005)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_102.npy']
# processing (0010)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_107.npy']
# processing (0015)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_111.npy']
# processing (0020)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_116.npy']
# processing (0025)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_120.npy']
# processing (0030)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_125.npy']
# processing (0035)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_13.npy']
# processing (0040)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_134.npy']
# processing (0045)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_139.npy']
# processing (0050)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_143.npy']
# processing (0055)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_148.npy']
# processing (0060)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_152.npy']
# processing (0065)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_157.npy']
# processing (0070)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_161.npy']
# processing (0075)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_166.npy']
# processing (0080)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_170.npy']
# processing (0085)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_175.npy']
# processing (0090)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_18.npy']
# processing (0095)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_184.npy']
# processing (0100)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_189.npy']
# processing (0105)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_193.npy']
# processing (0110)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_198.npy']
# processing (0115)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_201.npy']
# processing (0120)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_206.npy']
# processing (0125)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_210.npy']
# processing (0130)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_215.npy']
# processing (0135)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_22.npy']
# processing (0140)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_224.npy']
# processing (0145)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_229.npy']
# processing (0150)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_233.npy']
# processing (0155)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_238.npy']
# processing (0160)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_242.npy']
# processing (0165)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_247.npy']
# processing (0170)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_251.npy']
# processing (0175)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_256.npy']
# processing (0180)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_260.npy']
# processing (0185)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_265.npy']
# processing (0190)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_27.npy']
# processing (0195)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_274.npy']
# processing (0200)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_279.npy']
# processing (0205)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_283.npy']
# processing (0210)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_32.npy']
# processing (0215)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_37.npy']
# processing (0220)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_41.npy']
# processing (0225)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_46.npy']
# processing (0230)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_50.npy']
# processing (0235)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_55.npy']
# processing (0240)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_6.npy']
# processing (0245)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_64.npy']
# processing (0250)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_69.npy']
# processing (0255)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_73.npy']
# processing (0260)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_78.npy']
# processing (0265)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_82.npy']
# processing (0270)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_87.npy']
# processing (0275)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_91.npy']
# processing (0280)-th image... ['datasets/subj01_t1b_inv/test/subj01_pet_96.npy']
